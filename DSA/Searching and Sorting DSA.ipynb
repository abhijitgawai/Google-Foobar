# %% [markdown]
# # Reduce()

# %%
Mat=   [[10,20,30,40],
        [15,25,35,45],
        [27,29,37,48],
        [32,33,39,50]]
Mat
# Out:
# [[10, 20, 30, 40], [15, 25, 35, 45], [27, 29, 37, 48], [32, 33, 39, 50]]

# %%
a=np.array(Mat)

# %%
a=a.flatten(Mat)
a#.sort()
# Out:
# C:\Users\ABHI\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   """Entry point for launching an IPython kernel.
# array([10, 15, 27, 32, 20, 25, 29, 33, 30, 35, 37, 39, 40, 45, 48, 50])

# %%
from functools import reduce
input = [[41, 45, 20, 21], [1, 2, 3, 4], [30, 42, 43, 29], [16, 17, 19, 10]]
length_of_sublist = len(input[0])
sorted_list = iter(sorted(reduce(lambda x, y: x+ y, input), reverse=True))
print(list(zip(*[sorted_list] * length_of_sublist)))
# Out:
# [(45, 43, 42, 41), (30, 29, 21, 20), (19, 17, 16, 10), (4, 3, 2, 1)]

# %% [markdown]
# # Learn SORTING 2D ARRAYS

# %%
reduce(lambda x, y: x+ y, input)
# Out:
# [41, 45, 20, 21, 1, 2, 3, 4, 30, 42, 43, 29, 16, 17, 19, 10]

# %% [markdown]
# # 94	Find first and last positions of an element in a sorted array

# %%
arr=[1, 3, 5, 5, 5, 5, 67, 123, 125]
n=len(arr)
x=5

a=arr.index(x)
arr=arr[::-1]
b=n-arr.index(x)-1
return a,b
# Out:
# 2
# 3
# 4
# 5

# %%
arr=arr[::-1]
arr.index(x)
# Out:
# 3

# %%
#better
f=-1
l=-1
flag=0
for i in range(len(nums)):
    if nums[i]==target and flag==0:
        f=i
        flag=1

    if nums[i]==target:
        l=i
return [f,l]

# %% [markdown]
# # Binary Search

# %%
'''Recurssive'''
def binarySearch(a,l,r,x):
    print(a,l,r,x)
    
    mid=(l+r)//2
    print(a[mid])
#     if l>=r:
#         print('not found')
    if a[mid]==x:
        print('found at',mid)
    if a[mid]<x:
        l=mid
        binarySearch(a,l,r,x)
    if a[mid]>x:
        r=mid
        binarySearch(a,l,r,x)
    else:
        print('else')

a=[1, 2, 3, 4, 10, 16, 17, 19, 20, 21, 29, 30, 41, 42, 43, 45]
n=len(a)
x=3
binarySearch(a,0,n,x)
# Out:
# [1, 2, 3, 4, 10, 16, 17, 19, 20, 21, 29, 30, 41, 42, 43, 45] 0 16 3
# 20
# [1, 2, 3, 4, 10, 16, 17, 19, 20, 21, 29, 30, 41, 42, 43, 45] 0 8 3
# 10
# [1, 2, 3, 4, 10, 16, 17, 19, 20, 21, 29, 30, 41, 42, 43, 45] 0 4 3
# 3
# found at 2
# else

# %%
'''Iterative'''
a=[1, 2, 3, 4, 10, 16, 17, 19, 20, 21, 29, 30, 41, 42, 43, 45]
x=3
l=0
r=len(a)
while(l<=r):
    mid=(l+r)//2
    if a[mid]==x:
        print('Found at',mid)
        break
    if a[mid]<x:
        l=mid+1
    if a[mid]>x:
        r=mid-1
print('not found')
# Out:
# Found at 2
# not found

# %% [markdown]
# # Bubble sort

# %%
#bubble
a=[1, 2, 3, 4, 10, 16, 17, 19, 20, 21, 29, 30, 41, 42, 43, 45]
flag=False
for i in range(len(a)-1):
    flag=False
    for j in range(len(a)-1-i):
        if a[i]>a[i+1]:
            a[i],a[i+1]=a[i+1],a[i]
            flag=True
        if (flag!=True):
            break
            
a
# Out:
# [1, 2, 3, 4, 10, 16, 17, 19, 20, 21, 29, 30, 41, 42, 43, 45]

# %% [markdown]
# # 95	Find a Fixed Point (Value equal to index) in a given array

# %%
arr=[15, 2, 45, 12, 7]
N=len(arr)
arr,N
# Out:
# ([15, 2, 45, 12, 7], 5)

# %% [markdown]
# # 96	Search in a rotated sorted array

# %%
arr_=[i for i in range(1,N+1)]
arr_
# Out:
# [1, 2, 3, 4, 5]

# %%
'''O(n^2)'''
a=[]
for i in range(1,N+1):
    if arr[i-1]==i:
        print('foundat',i)
    
        a.append(i)
    print(i)
a
# Out:
# 1
# foundat 2
# 2
# 3
# 4
# 5
# [2]

# %%
'''O(logn) leetcode'''
def search(self, nums, target):
   lo, hi = 0, len(nums) - 1
   while lo <= hi:
       mid = (lo+hi) // 2
       if nums[mid] == target:
           return mid
       if nums[0] <= target < nums[mid] or target < nums[mid] < nums[0] or nums[mid] < nums[0] <= target:
           hi = mid - 1
       else:
           lo = mid + 1

   return -1
# Out:
# [2, 4]

# %% [markdown]
# # 97	square root of an integer

# %%
'''n^2 MY'''
N=9
a=[i**2 for i in range(1,N) if i**2<N]
print(len(a))
# Out:
# 2

# %%
'''n^2 MY'''
cnt=0
for i in range(1,N):
    if i**2<N:
        cnt+=1
    else:
        break
cnt
# Out:
# 2

# %%
'''1 MY'''
import math
a=math.ceil(math.sqrt(17))
a-1
# Out:
# 4

# %% [markdown]
# # 98	Maximum and minimum of an array using minimum number of comparisons

# %%
A=1
B=2
C=3
print( max(min(A,B),min(B,C))
# Out:
# 2
# 1

# %% [markdown]
# # Clamp

# %%
import torch
	
# A constant tensor of size n
a = torch.FloatTensor([1, 4, 6, 8, 10, 14])
print(a)

# Applying the clamp function and
# storing the result in 'out'
out = torch.clamp(a, min = 5, max = 10)
print(out)
# Out:
# tensor([ 1.,  4.,  6.,  8., 10., 14.])
# tensor([ 5.,  5.,  6.,  8., 10., 10.])

# %% [markdown]
# # 100	Find the repeating and the missing

# %%
from collections import Counter
a=[2,2]
b=Counter(a)
for i in b:
    if b[i] == 2:
        repeated=i

        #repeated, missing

#return repeated,int((len(a)*(len(a)+1))/2-(sum(a)-repeated))
print(repeated,int((len(a)*(len(a)+1))/2-(sum(a)-repeated)))
# Out:
# 2 1

# %% [markdown]
# # 101	find majority element

# %%
A=[1,3,3] #A=[1,3]
N=len(A)
from collections import Counter
a=Counter(A)
print()
for i in a:
    if a[i]>N/2:
        print (i)
print( -1)
# Out:
# 3
# -1

# %%
'''GFG O(n)'''
def findCandidate(self, A):
    maj_index = 0
    count = 1
    for i in range(len(A)):
        if A[maj_index] == A[i]:
            count += 1
        else:
            count -= 1
        if count == 0:
            maj_index = i
            count = 1
    return A[maj_index]

def isMajority(self, A, cand):
    count = 0
    for i in range(len(A)):
        if A[i] == cand:
            count += 1
    if count > len(A)/2:
        return True
    else:
        return False

def majorityElement(self, A,N):
    cand = self.findCandidate(A)
    if self.isMajority(A, cand) == True:
        return cand
    else:
        return -1

# %%
# Python3 program to demonstrate insert operation in binary
# search tree.
# class for creating node
class Node():
	def __init__(self, data):
		self.data = data
		self.left = None
		self.right = None
		self.count = 1 # count of number of times data is inserted in tree

# class for binary search tree
# it initialises tree with None root
# insert function inserts node as per BST rule
# and also checks for majority element
# if no majority element is found yet, it returns None


class BST():
	def __init__(self):
		self.root = None

	def insert(self, data, n):
		out = None
		if (self.root == None):
			self.root = Node(data)
		else:
			out = self.insertNode(self.root, data, n)
		return out

	def insertNode(self, currentNode, data, n):
		if (currentNode.data == data):
			currentNode.count += 1
			if (currentNode.count > n//2):
				return currentNode.data
			else:
				return None
		elif (currentNode.data < data):
			if (currentNode.right):
				self.insertNode(currentNode.right, data, n)
			else:
				currentNode.right = Node(data)
		elif (currentNode.data > data):
			if (currentNode.left):
				self.insertNode(currentNode.left, data, n)
			else:
				currentNode.left = Node(data)


# Driver code
# declaring an array
arr = [3, 2, 3]
n = len(arr)

# declaring None tree
tree = BST()
flag = 0
for i in range(n):
	out = tree.insert(arr[i], n)
	if (out != None):
		print(arr[i])
		flag = 1
		break
if (flag == 0):
	print("No Majority Element")
# Out:
# 3

# %% [markdown]
# # 103	find a pair with a given difference

# %%
arr=[3327,6546,9191,5756,3544,9033,2221,6794,1292,607,5685,160,5485,6104,844,2842,6313,4734,5040,6083,7795,9336,5941,5322,9319,4863,5905,4166,52,9372,7282,9730,2269,6473,5485,5813,1857,4057,2606,9501,4663,8290,9660,147,4394,504,9340,706,1589,4380,3141,5735,3715,9081,7408,9385,3943,3312,3550,346,9036,831,75,1304,3655,1911,7116,5512,2319,6073,1364,3333,715,1023,9831,5108,7878,9170,2165,5819,3549,1657,1553,3615,737,8961,2999,1031,8624,2900,7728,7659,83,4154,5315,3737,6064,8782,5600,4734,4855,696]
N=265
L=len(arr)
flag=-1
for i in range(L):
    for j in range(i,L):
        print(arr[i]-arr[j])
        if abs(arr[i]-arr[j])==N:
            print('found',arr[i])
            print('flag',flag)
            break
#return -1
# Out:
# 0
# -3219
# -5864
# -2429
# -217
# -5706
# 1106
# -3467
# 2035
# 2720
# -2358
# 3167
# -2158
# -2777
# 2483
# 485
# -2986
# -1407
# -1713
# -2756
# -4468
# -6009
# -2614
# -1995
# -5992
# -1536
# -2578
# -839
# 3275
# -6045
# -3955
# -6403
# 1058
# -3146
# -2158
# -2486
# 1470
# -730
# 721
# -6174
# -1336
# -4963
# -6333
# 3180
# -1067
# 2823
# -6013
# 2621
# 1738
# -1053
# 186
# -2408
# -388
# -5754
# -4081
# -6058
# -616
# 15
# -223
# 2981
# -5709
# 2496
# 3252
# 2023
# -328
# 1416
# -3789
# -2185
# 1008
# -2746
# 1963
# -6
# 2612
# 2304
# -6504
# -1781
# -4551
# -5843
# 1162
# -2492
# -222
# 1670
# 1774
# -288
# 2590
# -5634
# 328
# 2296
# -5297
# 427
# -4401
# -4332
# 3244
# -827
# -1988
# -410
# -2737
# -5455
# -2273
# -1407
# -1528
# 2631
# 0
# -2645
# 790
# 3002
# -2487
# 4325
# -248
# 5254
# 5939
# 861
# 6386
# 1061
# 442
# 5702
# 3704
# 233
# 1812
# 1506
# 463
# -1249
# -2790
# 605
# 1224
# -2773
# 1683
# 641
# 2380
# 6494
# -2826
# -736
# -3184
# 4277
# 73
# 1061
# 733
# ...

# %%
arr=[3327,6546,9191,5756,3544,9033,2221,6794,1292,607,5685,160,5485,6104,844,2842,6313,4734,5040,6083,7795,9336,5941,5322,9319,4863,5905,4166,52,9372,7282,9730,2269,6473,5485,5813,1857,4057,2606,9501,4663,8290,9660,147,4394,504,9340,706,1589,4380,3141,5735,3715,9081,7408,9385,3943,3312,3550,346,9036,831,75,1304,3655,1911,7116,5512,2319,6073,1364,3333,715,1023,9831,5108,7878,9170,2165,5819,3549,1657,1553,3615,737,8961,2999,1031,8624,2900,7728,7659,83,4154,5315,3737,6064,8782,5600,4734,4855,696]
N=265
L=len(arr)
flag=-1
for i in range(L):
    for j in range(i,L):
        xx=max(arr[i],arr[j])
        yy=min(arr[i],arr[j])
        #print(arr[i]-arr[j])
        if xx-yy==N:
            print('found',arr[i])
            print('flag',flag)
            break
#return -1
print(len(arr))
# Out:
# 102

# %%
x=78
arr=[5, 20, 3, 2, 5, 80]
n=len(arr)
s={}
for i in range(n):
    if abs(x-arr[i]) in s:
        print(arr[i])
        print(1) 
        
    else:
        s[arr[i]]=i
print(s)
print( -1)
# Out:
# 80
# 1
# {5: 4, 20: 1, 3: 2, 2: 3}
# -1

# %%
def findPair( arr, L,N):
        s={}
        for i in range(L):
            if abs(N-arr[i]) in s:
                return 1
                
            
            s[arr[i]]=1
        return -1
print(findPair([90, 70, 20, 80, 50],5,45))
# Out:
# -1

# %% [markdown]
# # 104	find four elements that sum to a given value

# %%
# Completed but GFG dont accept
def fourSum( a, k):
    # code here
    bb=[]

    from itertools import combinations
    a=set(combinations(a,4))

    for x in a:
        if x[0]+x[1]+x[2]+x[3]==k:
            #print(k)
            #return 
            bb.append([x[0],x[1],x[2],x[3]])

    for i in range(len(bb)):
        
        bb[i].sort()
    bb.sort()
    return bb
    #return sorted(bb,key=lambda x: (x[0],x[1],x[2],x[3]))
for i in(fourSum([88,84,3,51,54,99,32,60,76,68,39,12,26,86,94,39,95,70,34,78,67,1,97,2,17,92,52],179)):
    print(i)
# Out:
# [1, 2, 84, 92]
# [1, 3, 76, 99]
# [1, 3, 78, 97]
# [1, 12, 67, 99]
# [1, 12, 78, 88]
# [1, 17, 67, 94]
# [1, 26, 60, 92]
# [1, 26, 68, 84]
# [1, 32, 51, 95]
# [1, 32, 52, 94]
# [1, 32, 54, 92]
# [1, 32, 60, 86]
# [1, 32, 68, 78]
# [1, 32, 70, 76]
# [1, 34, 52, 92]
# [1, 34, 60, 84]
# [1, 34, 68, 76]
# [1, 39, 51, 88]
# [1, 51, 60, 67]
# [2, 3, 86, 88]
# [2, 12, 68, 97]
# [2, 12, 70, 95]
# [2, 17, 68, 92]
# [2, 17, 76, 84]
# [2, 26, 52, 99]
# [2, 26, 54, 97]
# [2, 26, 67, 84]
# [2, 32, 51, 94]
# [2, 32, 67, 78]
# [2, 34, 51, 92]
# [2, 34, 67, 76]
# [2, 39, 39, 99]
# [2, 39, 52, 86]
# [2, 39, 52, 86]
# [2, 39, 54, 84]
# [2, 39, 60, 78]
# [2, 39, 68, 70]
# [3, 12, 67, 97]
# [3, 12, 70, 94]
# [3, 12, 76, 88]
# [3, 12, 78, 86]
# [3, 17, 60, 99]
# [3, 17, 67, 92]
# [3, 26, 51, 99]
# [3, 32, 52, 92]
# [3, 32, 60, 84]
# [3, 32, 68, 76]
# [3, 34, 54, 88]
# [3, 39, 51, 86]
# [3, 39, 51, 86]
# [3, 39, 67, 70]
# [3, 52, 54, 70]
# [12, 17, 51, 99]
# [12, 32, 51, 84]
# [12, 32, 67, 68]
# ...

# %% [markdown]
# # find three elements that sum to a given value #leetcode

# %%
''' MY <<<O(n^2)'''
def threeSum(self, nums: List[int]) -> List[List[int]]:
    result=[]
    n=len(nums)
    nums.sort()
    for i in range(n-2):
        j=i+1
        k=n-1
        re=0
        while(j<k):
            #print(i,j,k)
            if 0<nums[i]+nums[j]+nums[k]:
                k-=1

            elif 0>nums[i]+nums[j]+nums[k]:
                j+=1nums

            elif nums[i]+arr[j]+arr[k]==0:
                if [nums[i],nums[j],nums[k]] not in result:
                    result.append([nums[i],nums[j],nums[k]])
                    #print(i,j,k,'+')
                    while(j<k   ):
                        if nums[j]==nums[j+1] :
                            j+=1
                        if nums[k]==nums[k-1]:
                            k-=1
                j+=1
                k-=1
return (result)

# %%
'''O(n^2) leetcode'''
def threeSum(self, nums: List[int]) -> List[List[int]]:
    ans = set([])
    plus = sorted([n for n in nums if n>0])
    plus_c = set(plus)
    zero = [n for n in nums if n == 0]
    minus = sorted([n for n in nums if n<0])
    minus_c = set(minus)
    # all zero
    if len(zero)>2:
        ans.add((0,0,0))
    # plus zero minus
    if len(zero)>0:
        for n in minus:
            if -n in plus_c:
                ans.add((n,0,-n))
    # plus minus minus
    n = len(minus)
    for i in range(n):
        for j in range(i+1,n):
            diff = -(minus[i]+minus[j])
            if diff in plus_c:
                ans.add((minus[i],minus[j],diff))
    # plus plus minus
    n = len(plus)
    for i in range(n):
        for j in range(i+1,n):
            diff = -(plus[i]+plus[j])
            if diff in minus_c:
                ans.add((diff,plus[i],plus[j]))
    return list(ans)

# %% [markdown]
# # 105	maximum sum such that no 2 elements are adjacent

# %%
'''MY DynamicP time-O(n), space-O(1) difficult to understand'''
#can also be done by taking a hashmap, return hashmap[-1]
a=[6, 7, 1, 3, 8, 2, 4]
n=len(a)

if n==0:
    print('end',0)
if n==1:
    print('end',a[0])
if n==2:
    print('end',max(a[0],a[1]))

else:
    n2=max(a[0],a[1])
    n1=a[0]
    
    for i in range(2,n):
        print(a[i]+n1,n2)
        t=max(a[i]+n1,n2)
        n1=n2
        n2=t
        
    print(n2)
    # c implemention with space O(n)
#     int FindMaxSum(int arr[], int n)
#     {
#         int dp[n];
#         dp[0] = arr[0];
#         dp[1] = max(arr[1],arr[0]);
        
#         for(int i=2;i<n;i++)
#         dp[i]  = max(dp[i-1],arr[i]+dp[i-2]);
        
#         return dp[n-1];
#     }
# Out:
# 7 7
# 10 7
# 15 10
# 12 15
# 19 15
# 19

# %% [markdown]
# # 106	Count triplet with sum smaller than a given value

# %%
'''MY TLE'''
arr=[30,8,23,6,10,9,31,7,19,20,1,33,21,27,28,3,25,26]
n=len(arr)
sumo=86
cnt=0
from itertools import combinations
a=combinations(arr,3)
for x in a:
    #print(x)
    if x[0]+x[1]+x[2]<sumo:
        print(x[0],x[1],x[2])
        cnt=cnt+1
print('cnt',cnt)
# Out:
# 30 8 23
# 30 8 6
# 30 8 10
# 30 8 9
# 30 8 31
# 30 8 7
# 30 8 19
# 30 8 20
# 30 8 1
# 30 8 33
# 30 8 21
# 30 8 27
# 30 8 28
# 30 8 3
# 30 8 25
# 30 8 26
# 30 23 6
# 30 23 10
# 30 23 9
# 30 23 31
# 30 23 7
# 30 23 19
# 30 23 20
# 30 23 1
# 30 23 21
# 30 23 27
# 30 23 28
# 30 23 3
# 30 23 25
# 30 23 26
# 30 6 10
# 30 6 9
# 30 6 31
# 30 6 7
# 30 6 19
# 30 6 20
# 30 6 1
# 30 6 33
# 30 6 21
# 30 6 27
# 30 6 28
# 30 6 3
# 30 6 25
# 30 6 26
# 30 10 9
# 30 10 31
# 30 10 7
# 30 10 19
# 30 10 20
# 30 10 1
# 30 10 33
# 30 10 21
# 30 10 27
# 30 10 28
# 30 10 3
# 30 10 25
# 30 10 26
# 30 9 31
# 30 9 7
# 30 9 19
# 30 9 20
# 30 9 1
# 30 9 33
# 30 9 21
# 30 9 27
# 30 9 28
# 30 9 3
# 30 9 25
# 30 9 26
# 30 31 7
# 30 31 19
# 30 31 20
# 30 31 1
# 30 31 21
# 30 31 3
# 30 7 19
# 30 7 20
# 30 7 1
# 30 7 33
# 30 7 21
# 30 7 27
# 30 7 28
# 30 7 3
# 30 7 25
# 30 7 26
# 30 19 20
# 30 19 1
# 30 19 33
# 30 19 21
# 30 19 27
# 30 19 28
# 30 19 3
# 30 19 25
# 30 19 26
# 30 20 1
# 30 20 33
# 30 20 21
# 30 20 27
# ...

# %%
'''MY TLE'''
len([x for x in combinations([30,8,23,6,10,9,31,7,19,20,1,33,21,27,28,3,25,26],3) if sum(x)<sumo])  #same and still TLE
# Out:
# 796

# %%
[x for x in combinations([30,8,23,6,10,9,31,7,19,20,1,33,21,27,28,3,25,26],2)]
# Out:
# [(30, 8),
#  (30, 23),
#  (30, 6),
#  (30, 10),
#  (30, 9),
#  (30, 31),
#  (30, 7),
#  (30, 19),
#  (30, 20),
#  (30, 1),
#  (30, 33),
#  (30, 21),
#  (30, 27),
#  (30, 28),
#  (30, 3),
#  (30, 25),
#  (30, 26),
#  (8, 23),
#  (8, 6),
#  (8, 10),
#  (8, 9),
#  (8, 31),
#  (8, 7),
#  (8, 19),
#  (8, 20),
#  (8, 1),
#  (8, 33),
#  (8, 21),
#  (8, 27),
#  (8, 28),
#  (8, 3),
#  (8, 25),
#  (8, 26),
#  (23, 6),
#  (23, 10),
#  (23, 9),
#  (23, 31),
#  (23, 7),
#  (23, 19),
#  (23, 20),
#  (23, 1),
#  (23, 33),
#  (23, 21),
#  (23, 27),
#  (23, 28),
#  (23, 3),
#  (23, 25),
#  (23, 26),
#  (6, 10),
#  (6, 9),
#  (6, 31),
#  (6, 7),
#  (6, 19),
#  (6, 20),
#  (6, 1),
#  (6, 33),
#  (6, 21),
#  (6, 27),
#  (6, 28),
#  (6, 3),
#  (6, 25),
#  (6, 26),
#  (10, 9),
#  (10, 31),
#  (10, 7),
#  (10, 19),
#  (10, 20),
#  (10, 1),
#  (10, 33),
#  (10, 21),
#  (10, 27),
#  (10, 28),
#  (10, 3),
#  (10, 25),
#  (10, 26),
#  (9, 31),
#  (9, 7),
#  (9, 19),
#  (9, 20),
#  (9, 1),
#  (9, 33),
# ...

# %%
'''MY TLE O(N^3)'''
cnt=0
sumo=86

arr=[30,8,23,6,10,9,31,7,19,20,1,33,21,27,28,3,25,26]
n=len(arr)
for i in range(0,n):
    for j in range(i+1,n):
        for k in range(j+1,n):
               if arr[i]+arr[j]+arr[k]<sumo:
                    cnt+=1
                    #print(arr[i],arr[j],arr[k])
print(cnt)
# Out:
# 796

# %%
'''O(n^2)'''
sumo=12
result=0
arr=[5, 1, 3, 4, 7]
n=len(arr)
arr.sort()
for i in range(n-2):
    j=i+1
    k=n-1
    re=0
    while(j<k):
        
        if sumo<=arr[i]+arr[j]+arr[k]:
            k-=1
            print(arr[i],arr[j],arr[k])
        else:
            print(arr[i],arr[j],arr[k],'re')
            result+=(k-j)
            #print(result)
            j+=1
print(result)
# Out:
# 1 3 7 re
# 3
# 1 4 5
# 1 4 5 re
# 4
# 3 4 5
# 3 4 4
# 4 5 5
# 4

# %% [markdown]
# # Sum of 3 ==0 leetcode #15

# %%
'''MY O(n^2)'''
def threeSum(arr):
    result=[]
    n=len(arr)
    arr.sort()
    for i in range(n-2):
        j=i+1
        k=n-1
        re=0
        while(j<k):
            print(i,j,k)
            if 0<arr[i]+arr[j]+arr[k]:
                k-=1
                
                #result.append
            elif 0>arr[i]+arr[j]+arr[k]:
                j+=1
                
                #print(arr[i],arr[j],arr[k])
            elif arr[i]+arr[j]+arr[k]==0:
                if [arr[i],arr[j],arr[k]] not in result:
                    result.append([arr[i],arr[j],arr[k]])
                    print(i,j,k,'+')
                    while(j<k and arr[j]==arr[j+1] ):
                        j+=1
                    while(j<k and arr[k]==arr[k-1]):
                        k-=1
                else:
                    j+=1
                    k-=1
                
    return (result)
print(threeSum([0,0,0,0]))
# Out:
# 0 1 3
# 0 1 3 +
# 1 2 3
# [[0, 0, 0]]

# %%
'''leetcode O(n^2)'''
def threeSum(self, nums: List[int]) -> List[List[int]]:
    ans = set([])
    plus = sorted([n for n in nums if n>0])
    plus_c = set(plus)
    zero = [n for n in nums if n == 0]
    minus = sorted([n for n in nums if n<0])
    minus_c = set(minus)
    # all zero
    if len(zero)>2:
        ans.add((0,0,0))
    # plus zero minus
    if len(zero)>0:
        for n in minus:
            if -n in plus_c:
                ans.add((n,0,-n))
    # plus minus minus
    n = len(minus)
    for i in range(n):
        for j in range(i+1,n):
            diff = -(minus[i]+minus[j])
            if diff in plus_c:
                ans.add((minus[i],minus[j],diff))
    # plus plus minus
    n = len(plus)
    for i in range(n):
        for j in range(i+1,n):
            diff = -(plus[i]+plus[j])
            if diff in minus_c:
                ans.add((diff,plus[i],plus[j]))
    return list(ans)

# %% [markdown]
# # 107	merge 2 sorted arrays

# %%
arr1=[1, 3, 5, 7]
arr2=[0, 2, 6, 8, 9]
n=len(arr1)
m=len(arr2)
print(arr1,arr2)
arr1=arr1+arr2
del(arr2)
arr1.sort()
print(arr1[0:n],arr1[n:])
arr2=arr1[n:]
arr1=arr1[0:n]
# Out:
# [1, 3, 5, 7] [0, 2, 6, 8, 9]
# [0, 1, 2, 3] [5, 6, 7, 8, 9]
